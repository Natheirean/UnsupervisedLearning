# %%
#Dependancies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# %%
#Load Data from CSV
file = "crypto_data.csv"
crypto_df = pd.read_csv(file, index_col=0)
crypto_df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42           42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365          365Coin       X11       True   PoW/PoS              NaN
# 404          404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611        SixEleven   SHA-256       True       PoW              NaN
# 808              808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# XBC      BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
#Drop all Crypto not being traded
crypto_active = crypto_df.loc[crypto_df.IsTrading==True].drop(columns="IsTrading")
crypto_active
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 365       365Coin          X11   PoW/PoS              NaN      2300000000
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 611     SixEleven      SHA-256       PoW              NaN          611000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# SERO   Super Zero       Ethash       PoW              NaN      1000000000
# UOS           UOS      SHA-256      DPoI              NaN      1000000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
#Remove rows with N/A
crypto_active = crypto_active.dropna(axis=0)
crypto_active
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
#Filter for coins that have been mined
crypto_active = crypto_active.loc[crypto_active.TotalCoinsMined > 0]
crypto_active
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
#Remove CoinName Column
crypto_active = crypto_active.drop(columns="CoinName")
crypto_active
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
crypto_dumb = pd.get_dummies(crypto_active[['Algorithm', 'ProofType']])
crypto_dumb = crypto_dumb.merge(crypto_active[['TotalCoinsMined', 'TotalCoinSupply']], how='inner', left_index=True, right_index=True)
crypto_dumb
# Out:
#       Algorithm_1GB AES Pattern Search  Algorithm_536  Algorithm_Argon2d  \
# 42                                   0              0                  0
# 404                                  0              0                  0
# 1337                                 0              0                  0
# BTC                                  0              0                  0
# ETH                                  0              0                  0
# ...                                ...            ...                ...
# ZEPH                                 0              0                  0
# GAP                                  0              0                  0
# BDX                                  0              0                  0
# ZEN                                  0              0                  0
# XBC                                  0              0                  0
#
#       Algorithm_BLAKE256  Algorithm_Blake  Algorithm_Blake2S  \
# ...

# %%
#Standardize Data
crypto_scaled = StandardScaler().fit_transform(crypto_dumb)

# %%
pca = PCA(n_components=.9)
df_pca = pca.fit_transform(crypto_scaled)
df_pca
# Out:
# array([[-3.35098808e-01,  1.03218907e+00, -5.90713438e-01, ...,
#          1.57796319e-14, -2.24512945e-16, -3.45465939e-15],
#        [-3.18433948e-01,  1.03233143e+00, -5.91125551e-01, ...,
#          1.61203319e-14, -3.16377817e-16, -3.46922826e-15],
#        [ 2.30546811e+00,  1.65638302e+00, -6.83616670e-01, ...,
#         -3.35514368e-13, -4.09100377e-15,  2.02990266e-14],
#        ...,
#        [ 3.24348535e-01, -2.31230764e+00,  4.21515366e-01, ...,
#          2.95719665e-13,  2.25527804e-13, -7.70912831e-13],
#        [-1.49363652e-01, -2.04933553e+00,  4.12968257e-01, ...,
#         -9.17319775e-15,  1.06352236e-15,  2.05947792e-15],
#        [-2.89957500e-01,  8.21194511e-01, -2.76326847e-01, ...,
#          1.03842300e-16,  5.02903432e-15,  2.49044219e-15]])

# %%
tsne = TSNE(learning_rate=100)
tsne_features = tsne.fit_transform(df_pca)
tsne_df = pd.DataFrame(data=tsne_features)
tsne_df
# Out:
#              0          1
# 0     2.350831 -13.581067
# 1     0.859027 -20.911310
# 2     4.178272 -27.284529
# 3    29.937168  -1.924182
# 4    -0.328637  21.603880
# ..         ...        ...
# 527  26.721855  -1.472430
# 528  -1.584307 -18.432886
# 529  16.168034  12.463274
# 530   7.525429  21.391998
# 531 -13.719384   8.040164
#
# [532 rows x 2 columns]

# %%
plt.scatter(tsne_df[0], tsne_df[1])
plt.show()

# %%
inertia = []
k=list(range(1,10))

for i in k:
    km = KMeans(n_clusters=i)
    km.fit(tsne_df)
    inertia.append(km.inertia_)
    
elbow_data ={"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow
# Out:
# C:\Users\deant\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
#    k        inertia
# 0  1  191917.281250
# 1  2  111173.375000
# 2  3   69398.554688
# 3  4   38264.992188
# 4  5   29004.978516
# 5  6   23035.402344
# 6  7   18761.380859
# 7  8   15363.478516
# 8  9   13014.702148

# %%
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,10))
plt.xlabel("Clusters")
plt.ylabel("Intertia")
plt.title("Elbow Curve")
plt.show()

# %%
#Crypto can be clustered together, there is a distict elbow between 3 and 4 clusters,
#so we can conclude that cyrpto can be clustered into 3 or 4 clusters.
